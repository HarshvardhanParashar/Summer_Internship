# %%
#Q.1
print("hello","Harsh",sep="-",end=".")
print('''\nFrom python
      this is new''')
# Out:
# hello-Harsh.
# From python
#       this is new

# %%
#Q.2
name= input("Enter your name: ")
print("Hello!", name)
# Out:
# Hello! HArsh
